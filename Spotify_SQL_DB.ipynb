# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
streaming_history_mine = pd.read_csv("Streaming_history.csv", encoding= 'unicode_escape') 
streaming_history_mine.head()
# Out:
#    Unnamed: 0           name  danceability  energy  key  loudness  mode  \
# 0           0  Wait For Life         0.262   0.469    5    -5.891     1
# 1           1         august         0.532   0.623    5    -9.208     1
# 2           2        Kudh Se         0.575   0.577    7    -6.674     1
# 3           3   Half a Heart         0.515   0.714    0    -4.516     1
# 4           4        Naan Un         0.470   0.521    6   -11.142     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0377         0.954          0.007900    0.1230   0.0756  117.895
# 1       0.0331         0.538          0.000073    0.0925   0.4030   89.937
# 2       0.0432         0.451          0.000004    0.2640   0.1570   90.012
# 3       0.0348         0.286          0.000000    0.1180   0.4950  155.954
# 4       0.0391         0.579          0.000003    0.1120   0.3280  142.266
#
#              type                      id  \
# ...

# %%
features=streaming_history_mine.iloc[:,1:61]

# %%
features.shape
# Out:
# (1924, 19)

# %%
features.head()
# Out:
#             name  danceability  energy  key  loudness  mode  speechiness  \
# 0  Wait For Life         0.262   0.469    5    -5.891     1       0.0377
# 1         august         0.532   0.623    5    -9.208     1       0.0331
# 2        Kudh Se         0.575   0.577    7    -6.674     1       0.0432
# 3   Half a Heart         0.515   0.714    0    -4.516     1       0.0348
# 4        Naan Un         0.470   0.521    6   -11.142     0       0.0391
#
#    acousticness  instrumentalness  liveness  valence    tempo            type  \
# 0         0.954          0.007900    0.1230   0.0756  117.895  audio_features
# 1         0.538          0.000073    0.0925   0.4030   89.937  audio_features
# 2         0.451          0.000004    0.2640   0.1570   90.012  audio_features
# 3         0.286          0.000000    0.1180   0.4950  155.954  audio_features
# 4         0.579          0.000003    0.1120   0.3280  142.266  audio_features
#
# ...

# %%
features.rename(columns={ features.columns[0]: "track_name" }, inplace = True)
features
# Out:
#          track_name  danceability  energy  key  loudness  mode  speechiness  \
# 0     Wait For Life         0.262   0.469    5    -5.891     1       0.0377
# 1            august         0.532   0.623    5    -9.208     1       0.0331
# 2           Kudh Se         0.575   0.577    7    -6.674     1       0.0432
# 3      Half a Heart         0.515   0.714    0    -4.516     1       0.0348
# 4           Naan Un         0.470   0.521    6   -11.142     0       0.0391
# ...             ...           ...     ...  ...       ...   ...          ...
# 1919  Mudher Kanave         0.692   0.709    2   -10.778     1       0.0502
# 1920       En Anbay         0.466   0.593   11   -10.981     1       0.1520
# 1921     Baarishein         0.475   0.124    2    -9.463     1       0.0444
# 1922  Black Beatles         0.794   0.632    0    -6.163     1       0.0649
# 1923       Kaatrile         0.648   0.592    0   -11.460     0       0.0787
#
# ...

# %%
songs_mine = pd.read_csv('Songsmine.csv')
songs_mine.drop('Unnamed: 0', axis=1, inplace=True)
songs_mine
# Out:
#               artist_name  ms_played                  track_name  \
# 0              Sid Sriram      23730  Inkem Inkem Inkem Kaavaale
# 1       Sabrina Carpenter      13467                   In My Bed
# 2            Emile Haynie     292280               Wait For Life
# 3     5 Seconds of Summer      10588                       Teeth
# 4                 Pradeep     230268           Aasai Oru Pulveli
# ...                   ...        ...                         ...
# 4749          A.R. Rahman      70880         Innum Konjam Naeram
# 4750          A.R. Rahman       9090                    Azhagiye
# 4751          A.R. Rahman      54642         Innum Konjam Naeram
# 4752          A.R. Rahman     243360             Khulke Jeene Ka
# 4753        L. V. Revanth     252286         Telisiney Na Nuvvey
#
#       minutes_played         day      time
# 0           0.395500  2019-09-14  04:29:00
# 1           0.224450  2019-09-15  03:47:00
# 2           4.871333  2019-09-15  03:52:00
# ...

# %%
songslist = pd.merge(songs_mine,features, on='track_name', how='inner')

# %%
songslist.rename(columns= {"id": "track_id"},inplace= True)

# %%
db_conn = sqlite3.connect(r"C:\Users\Niveatha\OneDrive\Niv\Spotify\SpotifyDB.db")

# %%
songslist.to_sql('spotify_streaming_history',db_conn, if_exists='append',index=False)
# Out:
# 4637
